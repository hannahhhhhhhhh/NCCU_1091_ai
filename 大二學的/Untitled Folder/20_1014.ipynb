# %%
import  matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.plot([1,2,3,4])

# %%
% matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5, 0.1)
y = x
plt.plot(x, y)
